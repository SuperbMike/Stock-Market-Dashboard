# %%
import requests

# Set up Hugging Face API
API_URL = "https://api-inference.huggingface.co/models/amphora/FinABSA-Longer"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

def check_predictions_exist(output):
    return "predictions" in output

# Define the title for which you want to check the predictions
title = "Example news article title"

# Define the payload for the API query
payload = {
    "inputs": title,
}

# Make the API query
output = query(payload)

# Check if the "predictions" key exists in the API response
if check_predictions_exist(output):
    print("Predictions exist!")
else:
    print("Predictions do not exist.")

# %%
import pandas as pd
import yfinance as yf

tickers = ['AAPL', 'GOOGL', 'MSFT', 'AMZN', 'FB', 'TSLA', 'NVDA', 'PYPL', 'NFLX', 'ADBE', 'INTC', 'CSCO', 'CMCSA', 'PEP', 'ABT', 'T', 'CRM', 'COST', 'AVGO', 'TXN', 'QCOM', 'ABBV', 'ACN', 'LMT', 'ABMD', 'ATVI', 'ADSK', 'ADP', 'BIIB', 'BKNG', 'BMY', 'AVB', 'BR', 'BAC', 'BK', 'BLK', 'BA', 'BSX', 'BMY', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CBRE', 'CELG', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'CTXS', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CAG', 'COP', 'ED', 'STZ', 'COO', 'CPRT', 'GLW', 'CTVA', 'COST', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DTE', 'DUK', 'DRE', 'DD', 'DXC', 'ETFC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ETR', 'EOG', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'EVRG', 'ES', 'RE', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FBHS', 'FRC', 'FDX', 'FIS', 'FITB', 'FE', 'FISV', 'FLT', 'FLIR', 'FLS', 'FMC', 'F', 'FTNT', 'FTV', 'FBHS', 'FOXA', 'FOX', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'GWW', 'HAL', 'HBI', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HFC', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IEX', 'IDXX', 'INFO', 'ITW', 'ILMN', 'INCY', 'IR', 'INTU', 'ISRG', 'IVZ', 'IP', 'IRM', 'JKHY', 'J', 'JBHT', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KSS', 'KHC', 'KR', 'LB', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LEG', 'LDOS', 'LEN', 'LLY', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MKC', 'MXIM', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NOV', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NSC', 'NTRS', 'NOC', 'NLOK', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'ORLY', 'OXY', 'ODFL', 'OMC', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SLG', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TXN', 'TXT', 'TMO', 'TIF', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TWTR', 'TYL', 'TSN', 'UDR', 'ULTA', 'USB', 'UAA', 'UA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UHS', 'UNM', 'VLO', 'VAR', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VIAC', 'VTRS', 'V', 'VNT', 'VNO', 'VMC', 'WRB', 'WAB', 'WMT', 'WBA', 'DIS', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WU', 'WRK', 'WY', 'WHR', 'WMB', 'WLTW', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']

# Create an empty DataFrame
data = pd.DataFrame()

# Iterate over each ticker
for ticker in tickers:
    try:
        # Create a Ticker object for the company
        company = yf.Ticker(ticker)
        
        # Retrieve the company's info and history
        info = company.info
        history = company.history(period='1d')
        
        # Add the company's info and history to the DataFrame
        info_series = pd.Series(info, name=ticker)
        data = data.append(info_series)
        data = data.append(history)
        
    except Exception as e:
        print(f"Error retrieving data for {ticker}: {e}")
        continue

# Display the resulting DataFrame
data.head()
# Out:
# C:\Users\mjbru\AppData\Local\Temp\ipykernel_5576\1380066763.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(info_series)
# C:\Users\mjbru\AppData\Local\Temp\ipykernel_5576\1380066763.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(history)
# C:\Users\mjbru\AppData\Local\Temp\ipykernel_5576\1380066763.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(info_series)
# C:\Users\mjbru\AppData\Local\Temp\ipykernel_5576\1380066763.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(history)
# ...

# %%
data.to_csv(r'C:\Users\mjbru\Documents\Coding\company_data.csv', index=False)

# %%
import yfinance as yf

# Define the ticker symbol
ticker = 'AAPL'

# Use yfinance to get the stock ticker symbol
stock = yf.Ticker(ticker)

# Get the stock news using yfinance
news = stock.news

# Print the article object to inspect its structure and keys
for article in news:
    print(article)
    break  # Print only the first article for demonstration purposes
# Out:
# {'uuid': '81a83561-1a26-39d7-9c59-bc5bddd4bc84', 'title': 'Netflix Shakes Up the World of Password-Sharing', 'publisher': 'Motley Fool', 'link': 'https://finance.yahoo.com/m/81a83561-1a26-39d7-9c59-bc5bddd4bc84/netflix-shakes-up-the-world.html', 'providerPublishTime': 1687387920, 'type': 'STORY', 'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/2IEbUSVX8QWvcocUVPHSRQ--~B/aD0xMDgwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/e0e51785741164a1ab6e92f43d10c81b', 'width': 1920, 'height': 1080, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/s.NLpkpxPp3v_.MtvkB8Ag--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/e0e51785741164a1ab6e92f43d10c81b', 'width': 140, 'height': 140, 'tag': '140x140'}]}, 'relatedTickers': ['NFLX', 'DIS', 'AMZN', 'PYPL', 'AAPL']}

# %%
# Make the API query
output = query(payload)

# Print the output dictionary
print(output)
# Out:
# [{'generated_text': 'The sentiment for[TGT] in the given sentence isNEUTRAL .'}]

# %%
parsed_data
# Out:
# []

# %%
import re
import requests
import pandas as pd

# Set up Hugging Face API
API_URL = "https://api-inference.huggingface.co/models/amphora/FinABSA-Longer"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

# Create an empty list to store the sentiment scores for each news article
sentiment_scores = []

# Process each news article
for item in parsed_data:
    ticker_symbol = item[0]
    title = item[3]

    # Add closing square bracket if not present
    if not ticker_symbol.endswith(']'):
        ticker_symbol += ']'

    # Define the payload for the API query
    payload = {
        "inputs": f"{ticker_symbol} {title}",
    }

    # Make the API query
    output = query(payload)

    if isinstance(output, list) and len(output) > 0:
        generated_text = output[0].get("generated_text")
        sentiment_match = re.search(r'sentiment is(\w+)', generated_text)
        if sentiment_match:
            sentiment = sentiment_match.group(1)
        else:
            sentiment = "UNKNOWN"
    else:
        sentiment = "UNKNOWN"

    # Append the sentiment to the list
    sentiment_scores.append(sentiment)

# Add the sentiment scores to the parsed_data list
for i in range(len(parsed_data)):
    parsed_data[i].append(sentiment_scores[i])

# Filter out articles with unknown sentiment
parsed_data = [data for data, sentiment in zip(parsed_data, sentiment_scores) if sentiment != "UNKNOWN"]

# Convert parsed_data to a Pandas DataFrame
df = pd.DataFrame(parsed_data, columns=['Ticker', 'Date', 'Company', 'Title', 'Published Date', 'Sentiment'])

# Save the DataFrame to a CSV file
df.to_csv('C:/Users/mjbru/Documents/Coding/Sentiment analysis work/sentiment_data.csv', index=False)

# Display the DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: [Ticker, Date, Company, Title, Published Date, Sentiment]
# Index: []

# %%
import yfinance as yf
from datetime import datetime

# Define the list of tickers you want to scrape news for
tickers = ['MMM', 'ABBV', 'ABT', 'ACN', 'ATVI', 'ADBE', 'AMD', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BKR', 'BLL', 'BAC', 'BK', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'BIIB', 'BLK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BF.B', 'CHRW', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CERN', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'CPRT', 'GLW', 'CTVA', 'COST', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DRE', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ENPH', 'ETR', 'EOG', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EVRG', 'ES', 'RE', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FRC', 'FISV', 'FLT', 'FLIR', 'FLS', 'FMC', 'F', 'FTNT', 'FTV', 'FBHS', 'FOXA', 'FOX', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'GWW', 'HAL', 'HBI', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HFC', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IEX', 'IDXX', 'INFO', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IBM', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IPGP', 'IQV', 'IRM', 'JKHY', 'J', 'JBHT', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LB', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LEG', 'LDOS', 'LEN', 'LLY', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MKC', 'MXIM', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NSC', 'NTRS', 'NOC', 'NLOK', 'NCLH', 'NOV', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'R', 'EGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK']

# Create an empty list to store the scraped news data
parsed_data = []

# Scrape news for each ticker
for ticker in tickers:
    # Use yfinance to get the stock ticker symbol
    stock = yf.Ticker(ticker)

    # Get the historical stock data
    history = stock.history(period='1d')
    if history.empty:
        print("No historical data available for the stock.")
    else:
        most_recent_date = history.index[-1].strftime('%Y-%m-%d')
        company_name = stock.info['longName']
        # Continue with the rest of your code

        # Get the stock news using yfinance
        news = stock.news

        # Process each news article
        for article in news:
            title = article['title']
            timestamp = article['providerPublishTime']

            # Convert epoch timestamp to a human-readable date
            date = datetime.fromtimestamp(timestamp).strftime('%Y-%m-%d')

            # Append the parsed data to the list
            parsed_data.append([ticker, most_recent_date, company_name, title, date])

# Convert the parsed data list to a Pandas DataFrame
df = pd.DataFrame(parsed_data, columns=['Ticker', 'Most Recent Date', 'Company Name', 'Title', 'Date'])

# Display the DataFrame
print(df)
# Out:
# AGN: No data found, symbol may be delisted
# No historical data available for the stock.
# ADS: No data found, symbol may be delisted
# No historical data available for the stock.
# ANTM: No data found, symbol may be delisted
# No historical data available for the stock.
# BLL: No data found, symbol may be delisted
# No historical data available for the stock.
# BRK.B: No data found, symbol may be delisted
# No historical data available for the stock.
# BF.B: Period '1d' is invalid, must be one of ['1mo', '3mo', '6mo', 'ytd', '1y', '2y', '5y', '10y', 'max']
# No historical data available for the stock.
# COG: No data found, symbol may be delisted
# No historical data available for the stock.
# CERN: No data found, symbol may be delisted
# No historical data available for the stock.
# CTXS: No data found, symbol may be delisted
# No historical data available for the stock.
# CXO: No data found, symbol may be delisted
# No historical data available for the stock.
# ...

# %%
df = pd.DataFrame(parsed_data, columns=['Ticker', 'Most Recent Date', 'Company Name', 'Title', 'Date'])
df
# Out:
#      Ticker Most Recent Date               Company Name  \
# 0       MMM       2023-06-22                 3M Company
# 1       MMM       2023-06-22                 3M Company
# 2       MMM       2023-06-22                 3M Company
# 3       MMM       2023-06-22                 3M Company
# 4       MMM       2023-06-22                 3M Company
# ...     ...              ...                        ...
# 2956    ROK       2023-06-22  Rockwell Automation, Inc.
# 2957    ROK       2023-06-22  Rockwell Automation, Inc.
# 2958    ROK       2023-06-22  Rockwell Automation, Inc.
# 2959    ROK       2023-06-22  Rockwell Automation, Inc.
# 2960    ROK       2023-06-22  Rockwell Automation, Inc.
#
#                                                   Title        Date
# 0       Down 25% in 12 Months, Is 3M Worth the Trouble?  2023-06-22
# 1                         Can 3M Stock Make a Comeback?  2023-06-21
# 2     At 3M, Lawsuits Threaten to Transform the Company  2023-06-21
# ...

# %%
# Check for missing values
missing_values = df.isna().sum()
print("Missing values:\n", missing_values)

# Drop rows with missing values
df = df.dropna()

# Check for duplicates
duplicates = df.duplicated()
print("Duplicates:\n", duplicates)

# Drop duplicate rows
df = df.drop_duplicates()

# Verify the updated dataframe
print("Updated dataframe:\n", df)
# Out:
# Missing values:
#  Ticker              0
# Most Recent Date    0
# Company Name        0
# Title               0
# Date                0
# dtype: int64
# Duplicates:
#  0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2956    False
# 2957    False
# 2958    False
# 2959    False
# 2960    False
# Length: 2961, dtype: bool
# Updated dataframe:
#       Ticker Most Recent Date               Company Name  \
# 0       MMM       2023-06-22                 3M Company
# 1       MMM       2023-06-22                 3M Company
# 2       MMM       2023-06-22                 3M Company
# 3       MMM       2023-06-22                 3M Company
# 4       MMM       2023-06-22                 3M Company
# ...     ...              ...                        ...
# 2956    ROK       2023-06-22  Rockwell Automation, Inc.
# 2957    ROK       2023-06-22  Rockwell Automation, Inc.
# 2958    ROK       2023-06-22  Rockwell Automation, Inc.
# ...

# %%
# Initialize an empty list to store the input strings
input_strings = []

# Iterate over the rows of the DataFrame
for _, row in df.iterrows():
    ticker = row['Ticker']
    company_name = row['Company Name']
    title = row['Title']

    # Construct the input string
    input_str = f"[{ticker}] {title}"
    input_strings.append(input_str)

# Print the input strings
for input_str in input_strings:
    print(input_str)
# Out:
# [MMM] Down 25% in 12 Months, Is 3M Worth the Trouble?
# [MMM] Can 3M Stock Make a Comeback?
# [MMM] At 3M, Lawsuits Threaten to Transform the Company
# [MMM] Why Is Everyone Talking About 3M Stock?
# [MMM] Did I Sell 3M Stock Too Soon?
# [MMM] Is 3M Stock Too Risky for Dividend Investors?
# [MMM] What Is 3M Company's (NYSE:MMM) Share Price Doing?
# [MMM] Exit Strategy: Get Out of These 3 Poor-Performing Stocks Now
# [ABBV] AbbVie Declares Quarterly Dividend
# [ABBV] Investors Heavily Search AbbVie Inc. (ABBV): Here is What You Need to Know
# [ABBV] 2 No-Brainer Healthcare Stocks to Buy Right Now
# [ABBV] The Zacks Analyst Blog Highlights PepsiCo, AbbVie, Honeywell, Salesforce and Goldman Sachs
# [ABBV] AbbVie (ABBV) Dips More Than Broader Markets: What You Should Know
# [ABBV] Top Analyst Reports for PepsiCo, AbbVie & Honeywell
# [ABBV] Lilly's (LLY) Migraine Drug Fails Vis-a-Vis Pfizer's Nurtec ODT
# [ABBV] This Biotech Is About to Eat AbbVie's Market Share, but Is It a Buy?
# ...

# %%
import pandas as pd
import requests
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Set up Hugging Face API
API_URL = "https://api-inference.huggingface.co/models/amphora/FinABSA-Longer"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()


# Create a new DataFrame to store the results
new_df = df.copy()
new_df['Sentiment'] = ''

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    ticker = row['Ticker']
    title = row['Title']

    # Generate the input sequence with the target aspect replaced by [TGT]
    input_str = re.sub(r'\b' + re.escape(ticker) + r'\b', '[TGT]', title)

    # Tokenize the input sequence
    inputs = tokenizer(input_str, return_tensors='pt')

    # Generate the sentiment prediction
    output = model.generate(**inputs, max_length=20)
    generated_text = tokenizer.decode(output[0])

    # Extract the sentiment label from the generated text
    sentiment_label = generated_text.split()[-1].strip(' .')

    # Store the sentiment label in the new DataFrame
    new_df.loc[index, 'Sentiment'] = sentiment_label

# Print the updated DataFrame
print(new_df)
# Out:
#      Ticker Most Recent Date               Company Name  \
# 0       MMM       2023-06-22                 3M Company
# 1       MMM       2023-06-22                 3M Company
# 2       MMM       2023-06-22                 3M Company
# 3       MMM       2023-06-22                 3M Company
# 4       MMM       2023-06-22                 3M Company
# ...     ...              ...                        ...
# 2956    ROK       2023-06-22  Rockwell Automation, Inc.
# 2957    ROK       2023-06-22  Rockwell Automation, Inc.
# 2958    ROK       2023-06-22  Rockwell Automation, Inc.
# 2959    ROK       2023-06-22  Rockwell Automation, Inc.
# 2960    ROK       2023-06-22  Rockwell Automation, Inc.
#
#                                                   Title        Date  \
# 0       Down 25% in 12 Months, Is 3M Worth the Trouble?  2023-06-22
# 1                         Can 3M Stock Make a Comeback?  2023-06-21
# 2     At 3M, Lawsuits Threaten to Transform the Company  2023-06-21
# ...

# %%
new_df
# Out:
#      Ticker Most Recent Date               Company Name  \
# 0       MMM       2023-06-22                 3M Company
# 1       MMM       2023-06-22                 3M Company
# 2       MMM       2023-06-22                 3M Company
# 3       MMM       2023-06-22                 3M Company
# 4       MMM       2023-06-22                 3M Company
# ...     ...              ...                        ...
# 2956    ROK       2023-06-22  Rockwell Automation, Inc.
# 2957    ROK       2023-06-22  Rockwell Automation, Inc.
# 2958    ROK       2023-06-22  Rockwell Automation, Inc.
# 2959    ROK       2023-06-22  Rockwell Automation, Inc.
# 2960    ROK       2023-06-22  Rockwell Automation, Inc.
#
#                                                   Title        Date  \
# 0       Down 25% in 12 Months, Is 3M Worth the Trouble?  2023-06-22
# 1                         Can 3M Stock Make a Comeback?  2023-06-21
# 2     At 3M, Lawsuits Threaten to Transform the Company  2023-06-21
# ...

# %%
new_df['Sentiment'] = new_df['Sentiment'].str.replace('is', '')
new_df
# Out:
#      Ticker Most Recent Date               Company Name  \
# 0       MMM       2023-06-22                 3M Company
# 1       MMM       2023-06-22                 3M Company
# 2       MMM       2023-06-22                 3M Company
# 3       MMM       2023-06-22                 3M Company
# 4       MMM       2023-06-22                 3M Company
# ...     ...              ...                        ...
# 2956    ROK       2023-06-22  Rockwell Automation, Inc.
# 2957    ROK       2023-06-22  Rockwell Automation, Inc.
# 2958    ROK       2023-06-22  Rockwell Automation, Inc.
# 2959    ROK       2023-06-22  Rockwell Automation, Inc.
# 2960    ROK       2023-06-22  Rockwell Automation, Inc.
#
#                                                   Title        Date Sentiment
# 0       Down 25% in 12 Months, Is 3M Worth the Trouble?  2023-06-22  POSITIVE
# 1                         Can 3M Stock Make a Comeback?  2023-06-21  NEGATIVE
# ...

# %%
new_df.to_csv('C:/Users/mjbru/Documents/Coding/Sentiment analysis work/Sentiment_analysisPOST', index=False)

# %%
print(f"Payload for index {index}: {payload}")
# Out:
# Payload for index 0: {'inputs': '[MMM] Down 25% in 12 Months, Is 3M Worth the Trouble?'}

# %%
# Call the API for sentiment analysis
sentiment_results = query(payload)

# Print the sentiment_results to inspect its structure
print(sentiment_results)
# Out:
# [{'generated_text': 'The sentiment for[TGT] in the given sentence isNEGATIVE .'}]

# %%
print(input_str)
# Out:
# [ROK] Rockwell Automation (ROK) Extends Its Partnership With PTC

# %%
# Initialize an empty list to store the input strings
input_strings = []

# Iterate over the rows of the DataFrame
for _, row in df.iterrows():
    ticker = row['Ticker']
    company_name = row['Company Name']
    title = row['Title']

    # Construct the input string
    input_str = f"[{ticker}] {title}"
    input_strings.append(input_str)

# Print the input strings
for input_str in input_strings:
    print(input_str)

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import pandas as pd

finviz_url = 'https://finviz.com/'
tickers = ['MMM', 'ABBV', 'ABT', 'ACN', 'ATVI', 'ADBE', 'AMD', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BKR', 'BLL', 'BAC', 'BK', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'BIIB', 'BLK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BF.B', 'CHRW', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CERN', 'CF', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'CPRT', 'GLW', 'CTVA', 'COST', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISCA', 'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DRE', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'EMR', 'ENPH', 'ETR', 'EOG', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EVRG', 'ES', 'RE', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FRC', 'FISV', 'FLT', 'FLIR', 'FLS', 'FMC', 'F', 'FTNT', 'FTV', 'FBHS', 'FOXA', 'FOX', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS', 'GWW', 'HAL', 'HBI', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HFC', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUM', 'HBAN', 'HII', 'IEX', 'IDXX', 'INFO', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IBM', 'IP', 'IPG', 'IFF', 'INTU', 'ISRG', 'IVZ', 'IPGP', 'IQV', 'IRM', 'JKHY', 'J', 'JBHT', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LB', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LEG', 'LDOS', 'LEN', 'LLY', 'LNC', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MKC', 'MXIM', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NSC', 'NTRS', 'NOC', 'NLOK', 'NCLH', 'NOV', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PBCT', 'PEP', 'PKI', 'PRGO', 'PFE', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'R', 'EGN', 'RF', 'RSG', 'RMD', 'RHI', 'ROK']
news_tables = {}
parsed_data = []

# Scrape news articles for each ticker
for ticker in tickers:
    url = finviz_url + ticker

    req = Request(url=url, headers=headers)
    response = urlopen(req)

    html = BeautifulSoup(response, 'html.parser')
    news_table = html.find(id='news-table')
    news_tables[ticker] = news_table

# Parse and process the news articles
for ticker, news_table in news_tables.items():
    for row in news_table.findAll('tr'):
        title = row.a.get_text()
        date_data = row.td.text.split(' ')

        if len(date_data) == 1:
            time = date_data[0]
        else:
            date = date_data[0]
            time = date_data[1]

        parsed_data.append([ticker, date, time, title])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[55], line 16
#      13 url = finviz_url + ticker
#      15 req = Request(url=url, headers=headers)
# ---> 16 response = urlopen(req)
#      18 html = BeautifulSoup(response, 'html.parser')
#      19 news_table = html.find(id='news-table')
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
# ...
